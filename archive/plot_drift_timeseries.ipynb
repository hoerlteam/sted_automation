# %%
from skimage.feature import blob_log
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
from Util.sift.util import read_image_stack
import os, re, sys
from spot_util import detect_blobs
from display_util import draw_detections_1c
import statsmodels.formula.api as sm
from sklearn import preprocessing
import itertools
from scipy.optimize import curve_fit
from multiprocessing import Pool

# %matplotlib inline

# %%
def cut(img, pos, size):
    pos = np.array(pos)
    size = np.array(size)
    interval = np.array(img.shape)
    mins = pos - (np.floor(size / 2))
    maxs = pos + (np.ceil(size / 2))
    
    #print(interval)
    
    to_pad = - np.min(mins) if np.min(mins) < 0 else (- np.min(interval - maxs) if np.min(interval - maxs) < 0 else 0)
    #to_pad = 0 if to_pad < 0 else to_pad
    #print(to_pad)
    mins += to_pad
    maxs += to_pad
    
    return np.pad(img, np.int(to_pad), 'constant')[mins[0]:maxs[0] , mins[1]:maxs[1], mins[2]:maxs[2]]
    
    print (mins, maxs)

def idxes(pos, size):
    pos = np.array(pos)
    size = np.array(size)
    mins = pos - (np.floor(size / 2))
    maxs = pos + (np.ceil(size / 2))
    
    return np.array(list(itertools.product(np.arange(mins[0], maxs[0]), np.arange(mins[1], maxs[1]), np.arange(mins[2], maxs[2]))))

def agauss(idx, *params):
    #print(idx)
    params = list(*params)
    #params = params
    return params[0] + params[1] * np.exp( -1/2 * ( (idx[0] - params[2])**2 / params[3]**2  + (idx[1] - params[4])**2 / params[5]**2 + (idx[2] - params[6])**2 / params[7]**2) )


def gausses(idxes, *params):
    return np.apply_along_axis(lambda x: agauss(x, params), 1, idxes)

def find_spot_lm(f):
    img = read_image_stack(f, True)
    dets = detect_blobs(np.array(img, np.float), [3, 3, 3], 5)
    
    if len(dets) == 1:
        
        _ys = cut(img, dets[0], [20, 20, 20]).ravel()
        _xs = idxes(dets[0], [20, 20, 20])
        
        pa, pcov = curve_fit(gausses, _xs, _ys, [0.0, np.max(img), dets[0][0], 1.0,  dets[0][1], 1.0, dets[0][2], 1.0])
        
        res = [pa[2], pa[4], pa[6]]
    else:
        res = [np.nan, np.nan, np.nan]

    
    print('finished file ' + f.split(os.sep)[-1])
    return res

# %%
# load temp curve
temp_curve = pd.read_table('/Volumes/project_data/agl_data/Optimisation-Maintainance/DavidHoerl/STED/goldbeads_over_time/log.txt')
temp_curve = temp_curve[10:]
plt.plot(temp_curve.time, temp_curve.temp)

# %%
# plot maximum projections

path = '/Volumes/project_data/agl_data/Optimisation-Maintainance/DavidHoerl/STED/goldbeads_over_time/tiffs'
files = [f for f in next(os.walk(path))[2] if f.endswith('.tif')]

p = '.*?_t([0-9]+?)\..*?'

files.sort(key = lambda x : int(re.match(p, x).groups()[0]))
files_ = [os.path.join(path, f) for f in files]

times = []
xs = []
ys = []
zs = []


service = Pool()
dets = service.map(find_spot_lm, files_)
# Out:
# finished file 20160928_goldbeads_t1475063246.msrch0.tif
# finished file 20160928_goldbeads_t1475062166.msrch0.tif
# finished file 20160928_goldbeads_t1475061626.msrch0.tif
# finished file 20160928_goldbeads_t1475062706.msrch0.tif
# finished file 20160928_goldbeads_t1475061086.msrch0.tif
# finished file 20160928_goldbeads_t1475063786.msrch0.tif
# finished file 20160928_goldbeads_t1475060007.msrch0.tif
# finished file 20160928_goldbeads_t1475060546.msrch0.tif
# finished file 20160928_goldbeads_t1475063306.msrch0.tiffinished file 20160928_goldbeads_t1475062226.msrch0.tiffinished file 20160928_goldbeads_t1475061686.msrch0.tiffinished file 20160928_goldbeads_t1475062766.msrch0.tiffinished file 20160928_goldbeads_t1475061146.msrch0.tiffinished file 20160928_goldbeads_t1475063846.msrch0.tiffinished file 20160928_goldbeads_t1475060066.msrch0.tiffinished file 20160928_goldbeads_t1475060606.msrch0.tif
#
#
#
#
#
#
#
# finished file 20160928_goldbeads_t1475063366.msrch0.tiffinished file 20160928_goldbeads_t1475062286.msrch0.tiffinished file 20160928_goldbeads_t1475061746.msrch0.tiffinished file 20160928_goldbeads_t1475062826.msrch0.tiffinished file 20160928_goldbeads_t1475061206.msrch0.tiffinished file 20160928_goldbeads_t1475063906.msrch0.tiffinished file 20160928_goldbeads_t1475060126.msrch0.tiffinished file 20160928_goldbeads_t1475060666.msrch0.tif
#
#
#
#
#
#
#
# finished file 20160928_goldbeads_t1475063426.msrch0.tiffinished file 20160928_goldbeads_t1475062346.msrch0.tiffinished file 20160928_goldbeads_t1475061806.msrch0.tiffinished file 20160928_goldbeads_t1475062886.msrch0.tiffinished file 20160928_goldbeads_t1475061266.msrch0.tiffinished file 20160928_goldbeads_t1475063966.msrch0.tiffinished file 20160928_goldbeads_t1475060186.msrch0.tiffinished file 20160928_goldbeads_t1475060726.msrch0.tif
#
#
#
#
#
#
#
# finished file 20160928_goldbeads_t1475063486.msrch0.tiffinished file 20160928_goldbeads_t1475062406.msrch0.tiffinished file 20160928_goldbeads_t1475061866.msrch0.tiffinished file 20160928_goldbeads_t1475062946.msrch0.tiffinished file 20160928_goldbeads_t1475061326.msrch0.tiffinished file 20160928_goldbeads_t1475064026.msrch0.tiffinished file 20160928_goldbeads_t1475060246.msrch0.tiffinished file 20160928_goldbeads_t1475060786.msrch0.tif
#
#
#
#
#
#
#
# finished file 20160928_goldbeads_t1475063546.msrch0.tiffinished file 20160928_goldbeads_t1475062466.msrch0.tiffinished file 20160928_goldbeads_t1475061926.msrch0.tiffinished file 20160928_goldbeads_t1475063006.msrch0.tiffinished file 20160928_goldbeads_t1475061386.msrch0.tiffinished file 20160928_goldbeads_t1475064086.msrch0.tiffinished file 20160928_goldbeads_t1475060306.msrch0.tiffinished file 20160928_goldbeads_t1475060846.msrch0.tif
#
#
#
#
#
#
#
# finished file 20160928_goldbeads_t1475063606.msrch0.tiffinished file 20160928_goldbeads_t1475062526.msrch0.tiffinished file 20160928_goldbeads_t1475061986.msrch0.tiffinished file 20160928_goldbeads_t1475063066.msrch0.tiffinished file 20160928_goldbeads_t1475061446.msrch0.tiffinished file 20160928_goldbeads_t1475064146.msrch0.tiffinished file 20160928_goldbeads_t1475060366.msrch0.tiffinished file 20160928_goldbeads_t1475060906.msrch0.tif
#
#
#
#
#
#
#
# finished file 20160928_goldbeads_t1475063666.msrch0.tiffinished file 20160928_goldbeads_t1475062586.msrch0.tiffinished file 20160928_goldbeads_t1475062046.msrch0.tiffinished file 20160928_goldbeads_t1475063126.msrch0.tiffinished file 20160928_goldbeads_t1475061506.msrch0.tiffinished file 20160928_goldbeads_t1475064206.msrch0.tiffinished file 20160928_goldbeads_t1475060426.msrch0.tiffinished file 20160928_goldbeads_t1475060966.msrch0.tif
#
#
#
#
#
#
#
# finished file 20160928_goldbeads_t1475063726.msrch0.tiffinished file 20160928_goldbeads_t1475062646.msrch0.tiffinished file 20160928_goldbeads_t1475062106.msrch0.tiffinished file 20160928_goldbeads_t1475063186.msrch0.tiffinished file 20160928_goldbeads_t1475061566.msrch0.tiffinished file 20160928_goldbeads_t1475064266.msrch0.tiffinished file 20160928_goldbeads_t1475060486.msrch0.tiffinished file 20160928_goldbeads_t1475061026.msrch0.tif
#
#
#
#
#
#
#
# finished file 20160928_goldbeads_t1475064326.msrch0.tiffinished file 20160928_goldbeads_t1475067567.msrch0.tiffinished file 20160928_goldbeads_t1475065406.msrch0.tiffinished file 20160928_goldbeads_t1475064866.msrch0.tiffinished file 20160928_goldbeads_t1475068107.msrch0.tiffinished file 20160928_goldbeads_t1475065947.msrch0.tiffinished file 20160928_goldbeads_t1475067027.msrch0.tiffinished file 20160928_goldbeads_t1475066487.msrch0.tif
#
#
#
#
#
#
#
# finished file 20160928_goldbeads_t1475064386.msrch0.tiffinished file 20160928_goldbeads_t1475067627.msrch0.tiffinished file 20160928_goldbeads_t1475065467.msrch0.tiffinished file 20160928_goldbeads_t1475064926.msrch0.tiffinished file 20160928_goldbeads_t1475068167.msrch0.tiffinished file 20160928_goldbeads_t1475066007.msrch0.tiffinished file 20160928_goldbeads_t1475067087.msrch0.tiffinished file 20160928_goldbeads_t1475066547.msrch0.tif
#
#
#
#
#
#
#
# finished file 20160928_goldbeads_t1475064446.msrch0.tiffinished file 20160928_goldbeads_t1475067687.msrch0.tiffinished file 20160928_goldbeads_t1475065526.msrch0.tiffinished file 20160928_goldbeads_t1475064986.msrch0.tiffinished file 20160928_goldbeads_t1475068227.msrch0.tiffinished file 20160928_goldbeads_t1475066067.msrch0.tiffinished file 20160928_goldbeads_t1475067147.msrch0.tiffinished file 20160928_goldbeads_t1475066607.msrch0.tif
#
#
#
#
#
#
#
# finished file 20160928_goldbeads_t1475064506.msrch0.tiffinished file 20160928_goldbeads_t1475067747.msrch0.tiffinished file 20160928_goldbeads_t1475065586.msrch0.tiffinished file 20160928_goldbeads_t1475065046.msrch0.tiffinished file 20160928_goldbeads_t1475068287.msrch0.tiffinished file 20160928_goldbeads_t1475066127.msrch0.tiffinished file 20160928_goldbeads_t1475067207.msrch0.tiffinished file 20160928_goldbeads_t1475066667.msrch0.tif
#
#
#
#
#
#
#
# finished file 20160928_goldbeads_t1475064566.msrch0.tiffinished file 20160928_goldbeads_t1475067807.msrch0.tiffinished file 20160928_goldbeads_t1475065647.msrch0.tiffinished file 20160928_goldbeads_t1475065107.msrch0.tiffinished file 20160928_goldbeads_t1475068347.msrch0.tiffinished file 20160928_goldbeads_t1475066187.msrch0.tiffinished file 20160928_goldbeads_t1475067267.msrch0.tiffinished file 20160928_goldbeads_t1475066727.msrch0.tif
#
#
#
#
#
#
#
# finished file 20160928_goldbeads_t1475064626.msrch0.tiffinished file 20160928_goldbeads_t1475067867.msrch0.tiffinished file 20160928_goldbeads_t1475065707.msrch0.tiffinished file 20160928_goldbeads_t1475065166.msrch0.tiffinished file 20160928_goldbeads_t1475068407.msrch0.tiffinished file 20160928_goldbeads_t1475066247.msrch0.tiffinished file 20160928_goldbeads_t1475067327.msrch0.tiffinished file 20160928_goldbeads_t1475066787.msrch0.tif
#
#
#
#
#
#
#
# finished file 20160928_goldbeads_t1475064686.msrch0.tiffinished file 20160928_goldbeads_t1475067927.msrch0.tiffinished file 20160928_goldbeads_t1475065766.msrch0.tiffinished file 20160928_goldbeads_t1475065226.msrch0.tiffinished file 20160928_goldbeads_t1475068467.msrch0.tiffinished file 20160928_goldbeads_t1475066307.msrch0.tiffinished file 20160928_goldbeads_t1475067387.msrch0.tiffinished file 20160928_goldbeads_t1475066847.msrch0.tif
#
#
#
#
#
#
#
# finished file 20160928_goldbeads_t1475064746.msrch0.tiffinished file 20160928_goldbeads_t1475067987.msrch0.tiffinished file 20160928_goldbeads_t1475065827.msrch0.tiffinished file 20160928_goldbeads_t1475065286.msrch0.tiffinished file 20160928_goldbeads_t1475068527.msrch0.tiffinished file 20160928_goldbeads_t1475066367.msrch0.tiffinished file 20160928_goldbeads_t1475067447.msrch0.tiffinished file 20160928_goldbeads_t1475066907.msrch0.tif
# /usr/local/lib/python3.5/site-packages/ipykernel/__main__.py:19: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /usr/local/lib/python3.5/site-packages/ipykernel/__main__.py:19: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /usr/local/lib/python3.5/site-packages/ipykernel/__main__.py:19: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /usr/local/lib/python3.5/site-packages/ipykernel/__main__.py:19: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /usr/local/lib/python3.5/site-packages/ipykernel/__main__.py:19: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /usr/local/lib/python3.5/site-packages/ipykernel/__main__.py:19: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /usr/local/lib/python3.5/site-packages/ipykernel/__main__.py:19: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /usr/local/lib/python3.5/site-packages/ipykernel/__main__.py:19: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-9977c0f1b2a5> in <module>()
#      19
#      20 for i in range(len(files)):
# ---> 21     t = int(re.match(p, f).groups()[0])
#      22     times.append(t)
#      23
#
# NameError: name 'f' is not defined
# finished file 20160928_goldbeads_t1475064806.msrch0.tiffinished file 20160928_goldbeads_t1475068047.msrch0.tiffinished file 20160928_goldbeads_t1475065887.msrch0.tiffinished file 20160928_goldbeads_t1475065346.msrch0.tiffinished file 20160928_goldbeads_t1475068587.msrch0.tiffinished file 20160928_goldbeads_t1475066427.msrch0.tiffinished file 20160928_goldbeads_t1475067507.msrch0.tiffinished file 20160928_goldbeads_t1475066967.msrch0.tif
#
#
#
#
#
#
#
# finished file 20160928_goldbeads_t1475068647.msrch0.tiffinished file 20160928_goldbeads_t1475073507.msrch0.tiffinished file 20160928_goldbeads_t1475069727.msrch0.tiffinished file 20160928_goldbeads_t1475069187.msrch0.tiffinished file 20160928_goldbeads_t1475071347.msrch0.tiffinished file 20160928_goldbeads_t1475070267.msrch0.tiffinished file 20160928_goldbeads_t1475071887.msrch0.tiffinished file 20160928_goldbeads_t1475070807.msrch0.tif
#
#
#
#
#
#
#
# finished file 20160928_goldbeads_t1475068707.msrch0.tiffinished file 20160928_goldbeads_t1475073567.msrch0.tiffinished file 20160928_goldbeads_t1475069787.msrch0.tiffinished file 20160928_goldbeads_t1475069247.msrch0.tiffinished file 20160928_goldbeads_t1475071407.msrch0.tiffinished file 20160928_goldbeads_t1475070327.msrch0.tiffinished file 20160928_goldbeads_t1475071947.msrch0.tiffinished file 20160928_goldbeads_t1475070867.msrch0.tif
#
#
#
#
#
#
#
# finished file 20160928_goldbeads_t1475068767.msrch0.tiffinished file 20160928_goldbeads_t1475073627.msrch0.tiffinished file 20160928_goldbeads_t1475069847.msrch0.tiffinished file 20160928_goldbeads_t1475069307.msrch0.tiffinished file 20160928_goldbeads_t1475071467.msrch0.tiffinished file 20160928_goldbeads_t1475070387.msrch0.tiffinished file 20160928_goldbeads_t1475072007.msrch0.tiffinished file 20160928_goldbeads_t1475070927.msrch0.tif
#
#
#
#
#
#
#
# finished file 20160928_goldbeads_t1475068827.msrch0.tiffinished file 20160928_goldbeads_t1475073687.msrch0.tiffinished file 20160928_goldbeads_t1475069907.msrch0.tiffinished file 20160928_goldbeads_t1475069367.msrch0.tiffinished file 20160928_goldbeads_t1475071527.msrch0.tiffinished file 20160928_goldbeads_t1475070447.msrch0.tiffinished file 20160928_goldbeads_t1475072067.msrch0.tiffinished file 20160928_goldbeads_t1475070987.msrch0.tif
#
#
#
#
#
#
#
# finished file 20160928_goldbeads_t1475068887.msrch0.tiffinished file 20160928_goldbeads_t1475073747.msrch0.tiffinished file 20160928_goldbeads_t1475069967.msrch0.tiffinished file 20160928_goldbeads_t1475069427.msrch0.tiffinished file 20160928_goldbeads_t1475071587.msrch0.tiffinished file 20160928_goldbeads_t1475070507.msrch0.tiffinished file 20160928_goldbeads_t1475072127.msrch0.tiffinished file 20160928_goldbeads_t1475071047.msrch0.tif
#
#
#
#
#
#
#
# finished file 20160928_goldbeads_t1475068947.msrch0.tiffinished file 20160928_goldbeads_t1475073807.msrch0.tiffinished file 20160928_goldbeads_t1475070027.msrch0.tiffinished file 20160928_goldbeads_t1475069487.msrch0.tiffinished file 20160928_goldbeads_t1475071647.msrch0.tiffinished file 20160928_goldbeads_t1475070567.msrch0.tiffinished file 20160928_goldbeads_t1475072187.msrch0.tiffinished file 20160928_goldbeads_t1475071107.msrch0.tif
#
#
#
#
#
#
#
# finished file 20160928_goldbeads_t1475069007.msrch0.tiffinished file 20160928_goldbeads_t1475073867.msrch0.tiffinished file 20160928_goldbeads_t1475070087.msrch0.tiffinished file 20160928_goldbeads_t1475069547.msrch0.tiffinished file 20160928_goldbeads_t1475071707.msrch0.tiffinished file 20160928_goldbeads_t1475070627.msrch0.tiffinished file 20160928_goldbeads_t1475072247.msrch0.tiffinished file 20160928_goldbeads_t1475071167.msrch0.tif
#
#
#
#
#
#
#
# finished file 20160928_goldbeads_t1475069067.msrch0.tiffinished file 20160928_goldbeads_t1475073927.msrch0.tiffinished file 20160928_goldbeads_t1475070147.msrch0.tiffinished file 20160928_goldbeads_t1475069607.msrch0.tiffinished file 20160928_goldbeads_t1475071767.msrch0.tiffinished file 20160928_goldbeads_t1475070687.msrch0.tiffinished file 20160928_goldbeads_t1475072307.msrch0.tiffinished file 20160928_goldbeads_t1475071227.msrch0.tif
#
#
#
#
#
#
#
# finished file 20160928_goldbeads_t1475069127.msrch0.tiffinished file 20160928_goldbeads_t1475073987.msrch0.tiffinished file 20160928_goldbeads_t1475070207.msrch0.tiffinished file 20160928_goldbeads_t1475069667.msrch0.tiffinished file 20160928_goldbeads_t1475071827.msrch0.tiffinished file 20160928_goldbeads_t1475070747.msrch0.tiffinished file 20160928_goldbeads_t1475072367.msrch0.tiffinished file 20160928_goldbeads_t1475071287.msrch0.tif
#
#
#
#
#
#
#
# finished file 20160928_goldbeads_t1475072427.msrch0.tiffinished file 20160928_goldbeads_t1475075127.msrch0.tiffinished file 20160928_goldbeads_t1475074047.msrch0.tiffinished file 20160928_goldbeads_t1475072967.msrch0.tiffinished file 20160928_goldbeads_t1475075667.msrch0.tiffinished file 20160928_goldbeads_t1475074587.msrch0.tiffinished file 20160928_goldbeads_t1475076207.msrch0.tif
#
#
#
#
#
#
# finished file 20160928_goldbeads_t1475072487.msrch0.tiffinished file 20160928_goldbeads_t1475075187.msrch0.tiffinished file 20160928_goldbeads_t1475074107.msrch0.tiffinished file 20160928_goldbeads_t1475073027.msrch0.tiffinished file 20160928_goldbeads_t1475075727.msrch0.tiffinished file 20160928_goldbeads_t1475074647.msrch0.tiffinished file 20160928_goldbeads_t1475076267.msrch0.tif
#
#
#
#
#
#
# finished file 20160928_goldbeads_t1475072547.msrch0.tiffinished file 20160928_goldbeads_t1475075247.msrch0.tiffinished file 20160928_goldbeads_t1475074167.msrch0.tiffinished file 20160928_goldbeads_t1475073087.msrch0.tiffinished file 20160928_goldbeads_t1475075787.msrch0.tiffinished file 20160928_goldbeads_t1475074707.msrch0.tiffinished file 20160928_goldbeads_t1475076327.msrch0.tif
#
#
#
#
#
#
# finished file 20160928_goldbeads_t1475072607.msrch0.tiffinished file 20160928_goldbeads_t1475075307.msrch0.tiffinished file 20160928_goldbeads_t1475074227.msrch0.tiffinished file 20160928_goldbeads_t1475073147.msrch0.tiffinished file 20160928_goldbeads_t1475075847.msrch0.tiffinished file 20160928_goldbeads_t1475074767.msrch0.tiffinished file 20160928_goldbeads_t1475076387.msrch0.tif
#
#
#
#
#
#
# finished file 20160928_goldbeads_t1475072667.msrch0.tiffinished file 20160928_goldbeads_t1475075367.msrch0.tiffinished file 20160928_goldbeads_t1475074287.msrch0.tiffinished file 20160928_goldbeads_t1475073207.msrch0.tiffinished file 20160928_goldbeads_t1475075907.msrch0.tiffinished file 20160928_goldbeads_t1475074827.msrch0.tiffinished file 20160928_goldbeads_t1475076447.msrch0.tif
#
#
#
#
#
#
# finished file 20160928_goldbeads_t1475072727.msrch0.tiffinished file 20160928_goldbeads_t1475075427.msrch0.tiffinished file 20160928_goldbeads_t1475074347.msrch0.tiffinished file 20160928_goldbeads_t1475073267.msrch0.tiffinished file 20160928_goldbeads_t1475075967.msrch0.tiffinished file 20160928_goldbeads_t1475074887.msrch0.tiffinished file 20160928_goldbeads_t1475076507.msrch0.tif
#
#
#
#
#
#
# finished file 20160928_goldbeads_t1475072787.msrch0.tiffinished file 20160928_goldbeads_t1475075487.msrch0.tiffinished file 20160928_goldbeads_t1475074407.msrch0.tiffinished file 20160928_goldbeads_t1475073327.msrch0.tiffinished file 20160928_goldbeads_t1475076027.msrch0.tiffinished file 20160928_goldbeads_t1475074947.msrch0.tiffinished file 20160928_goldbeads_t1475076567.msrch0.tif
#
#
#
#
#
#
# finished file 20160928_goldbeads_t1475072847.msrch0.tiffinished file 20160928_goldbeads_t1475075547.msrch0.tiffinished file 20160928_goldbeads_t1475074467.msrch0.tiffinished file 20160928_goldbeads_t1475073387.msrch0.tiffinished file 20160928_goldbeads_t1475076087.msrch0.tiffinished file 20160928_goldbeads_t1475075007.msrch0.tiffinished file 20160928_goldbeads_t1475076627.msrch0.tif
#
#
#
#
#
#
# finished file 20160928_goldbeads_t1475072907.msrch0.tiffinished file 20160928_goldbeads_t1475075607.msrch0.tiffinished file 20160928_goldbeads_t1475074527.msrch0.tiffinished file 20160928_goldbeads_t1475073447.msrch0.tiffinished file 20160928_goldbeads_t1475076147.msrch0.tiffinished file 20160928_goldbeads_t1475075067.msrch0.tiffinished file 20160928_goldbeads_t1475076687.msrch0.tif
#
#
#
#
#
#
# finished file 20160928_goldbeads_t1475076747.msrch0.tif
# finished file 20160928_goldbeads_t1475076807.msrch0.tif
# finished file 20160928_goldbeads_t1475076867.msrch0.tif
# finished file 20160928_goldbeads_t1475076927.msrch0.tif

# %%
for i in range(len(files)):
    t = int(re.match(p, files[i]).groups()[0])
    times.append(t)
    
    det = dets[i]    
    xs.append(det[0])
    ys.append(det[1])
    zs.append(det[2])

    #sys.stdout.write('\rfinished ' + str(i) + '/' + str(len(files)))
    #print('\rfinished ' + str(i) + '/' + str(len(files)))
    
pos_series = pd.DataFrame({'time' : times, 'x' : xs, 'y': ys, 'z' : zs})

# %%
pos_series['temp'] = temp_curve.rolling(window=60,center=False).mean()[temp_curve.time.isin(pos_series.time)].reset_index().temp
pos_series
#print(pd.rolling_mean(temp_curve.temp, 60))

minmx = preprocessing.MinMaxScaler()
#print(pos_series.temp.diff())


fig, ax = plt.subplots()
ax.plot(pos_series.time[1:], minmx.fit_transform(pos_series.temp.diff()[1:].reshape(-1, 1)))
ax.plot(pos_series.dropna().time, minmx.fit_transform(pos_series.dropna().x.reshape(-1, 1)))

result =  sm.ols(formula="z ~ temp + I(temp.diff())", data=pos_series).fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      z   R-squared:                       0.215
# Model:                            OLS   Adj. R-squared:                  0.204
# Method:                 Least Squares   F-statistic:                     18.68
# Date:                Fri, 30 Sep 2016   Prob (F-statistic):           6.82e-08
# Time:                        14:18:04   Log-Likelihood:                -453.32
# No. Observations:                 139   AIC:                             912.6
# Df Residuals:                     136   BIC:                             921.4
# Df Model:                           2
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------
# Intercept      -1048.8854    213.713     -4.908      0.000     -1471.516  -626.255
# temp              45.9690      8.998      5.109      0.000        28.176    63.762
# I(temp.diff())    94.5394     19.850      4.763      0.000        55.284   133.795
# ==============================================================================
# Omnibus:                        0.560   Durbin-Watson:                   0.508
# Prob(Omnibus):                  0.756   Jarque-Bera (JB):                0.624
# Skew:                          -0.147   Prob(JB):                        0.732
# Kurtosis:                       2.855   Cond. No.                     9.40e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.4e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
#plt.imshow(np.apply_along_axis(np.max, 2, img))
#np.cross(np.arange(0, 5), (np.arange(0,5)))
#print(np.array(list(itertools.product((np.arange(2), np.arange(3))))))

img = read_image_stack(os.path.join(path, files[0]), True)
dets = detect_blobs(np.array(img, np.float), [3, 3, 3], 5)

print(dets[0])
plt.imshow(np.apply_along_axis(np.max, 2, cut(img, dets[0], [20, 20, 20])))
plt.show()
ys = cut(img, dets[0], [20, 20, 20]).ravel()
xs = idxes(dets[0], [20, 20, 20])

#print(xs)

#print(gausses(xs, *[0.0, np.max(img), dets[0][0], 1.0,  dets[0][1], 1.0, dets[0][2], 1.0]))

pa, pcov = curve_fit(gausses, xs, ys, [0.0, np.max(img), dets[0][0], 1.0,  dets[0][1], 1.0, dets[0][2], 1.0])

plt.imshow(np.apply_along_axis(np.max, 2, gausses(xs, *pa).reshape(20, 20, 20)))
plt.show()
