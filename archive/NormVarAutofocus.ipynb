# %%
import skimage
import skimage.data
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
img = skimage.data.binary_blobs(100, n_dim=3)

# dimensions of image
sh = np.shape(img)

#np.var(img[:,:,3]) / np.mean(img[:,:,3])

dimension = 1

normvar = []
for i in range(sh[dimension]):
    # get slice i
    
    tImg = img[:,:,i]
    
    # try this for all dimensions <= 3
    if (dimension == 1):
        tImg = img[:,i,:]
    
    # edge-filter slice
    tImg = skimage.filters.sobel(tImg)
    # calculate var/mean
    normvar.append(np.var(tImg) / np.mean(tImg))
    
plt.plot(normvar)

#print maximum index
print(normvar.index(max(normvar)))
# Out:
# 0
